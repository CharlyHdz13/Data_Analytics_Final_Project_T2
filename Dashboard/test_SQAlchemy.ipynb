# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, MetaData, Table
from config import db_password

import pandas as pd

import os

# %%
db_string = f"postgresql://postgres:{db_password}@data-analytics-final-project-t2.ceptpmc0vrha.us-east-1.rds.amazonaws.com/Medical_Data"

# %%
engine = create_engine(db_string)

# %%
inspector = inspect(engine)
patients_df = pd.read_sql_table('patients_clusters',db_string, index_col='identification')
patients_df.head()
# Out:
#                healthcare_center  covid_test_negative  covid_test_positive  \
# identification
# 1                           INER                False                 True
# 2                           INER                False                 True
# 3                           INER                False                 True
# 4                           INER                False                 True
# 5                           INER                False                 True
#
#                pcr_antigen  inclusion_positive_covid_tests  exclusion_nofile  \
# identification
# 1                      PCR                            True             False
# 2                      PCR                            True             False
# 3                      PCR                            True             False
# 4                      PCR                            True             False
# 5                      PCR                            True             False
#
# ...

# %%
os.mkdir('Resources')

# %%
patients_df.to_json('Resources/patients.json', orient='records')

# %%
patients_df.to_csv('patients.csv')

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# %%
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)

# %%
# Print all of the classes mapped to the Base
Base.classes.keys()
# Out:
# ['comorbilities']

# %%
comorbilities = Base.classes.comorbilities
# Out:
# <class 'sqlalchemy.ext.automap.comorbilities'>

# %%
# Create a session
session = Session(engine)

# %%
test=session.query(comorbilities.smoking).all()

# %%
test
# Out:
# [(False,),
#  (True,),
#  (False,),
#  (True,),
#  (True,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (True,),
#  (False,),
#  (True,),
#  (False,),
#  (False,),
#  (True,),
#  (False,),
#  (False,),
#  (True,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (True,),
#  (True,),
#  (False,),
#  (True,),
#  (False,),
#  (True,),
#  (False,),
#  (False,),
#  (True,),
#  (False,),
#  (True,),
#  (False,),
#  (True,),
#  (False,),
#  (True,),
#  (False,),
#  (True,),
#  (False,),
#  (True,),
#  (True,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (True,),
#  (True,),
#  (False,),
#  (False,),
#  (True,),
#  (False,),
#  (False,),
#  (True,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (True,),
#  (False,),
#  (False,),
#  (False,),
#  (False,),
#  (True,),
#  (False,),
#  (False,),
#  (True,),
#  (False,),
#  (False,),
#  (True,),
#  (False,),
#  (True,),
#  (False,),
#  (True,),
#  (False,),
#  (False,),
#  (False,),
#  (True,),
# ...

# %%
# Use SQL to query 'all' the records in the the Database 
data = engine.execute("SELECT * FROM comorbilities")
for row in data:
    print(row)
# Out:
# ('1', True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False)
# ('2', True, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False)
# ('3', False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False)
# ('4', True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False)
# ('5', True, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False)
# ('6', True, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False)
# ('7', True, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False)
# ('8', True, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False)
# ...

# %%
# Create the inspector and connect it to the engine
inspector = inspect(engine)
# Using the inspector to print the column names within the 'dow' table and its types
columns = [column['name'] for column in inspector.get_columns('comorbilities')]

# %%
columns
# Out:
# ['identification',
#  'comorbilities',
#  'obesity',
#  'diabetes_mellitus',
#  'arterial_hypertension',
#  'autoimmune_disease',
#  'immunosuppression',
#  'cancer',
#  'smoking',
#  'alcoholism',
#  'copd',
#  'interstitial_lung_disease',
#  'tuberculosis',
#  'asthma',
#  'cardiovascular_disease',
#  'renal_disease',
#  'hepatic_disease',
#  'neurological_disease']

# %%
#  Create a meta data object to hold the reflected table schema
metadata = MetaData()

# %%
# Create a table object and use 'autoload' and 'autoload_with' to define the columns from the table. 
table = Table('comorbilities', metadata, autoload=True, autoload_with=engine)

# %%
table
# Out:
# Table('comorbilities', MetaData(), Column('identification', VARCHAR(), table=<comorbilities>, primary_key=True, nullable=False), Column('comorbilities', BOOLEAN(), table=<comorbilities>), Column('obesity', BOOLEAN(), table=<comorbilities>), Column('diabetes_mellitus', BOOLEAN(), table=<comorbilities>), Column('arterial_hypertension', BOOLEAN(), table=<comorbilities>), Column('autoimmune_disease', BOOLEAN(), table=<comorbilities>), Column('immunosuppression', BOOLEAN(), table=<comorbilities>), Column('cancer', BOOLEAN(), table=<comorbilities>), Column('smoking', BOOLEAN(), table=<comorbilities>), Column('alcoholism', BOOLEAN(), table=<comorbilities>), Column('copd', BOOLEAN(), table=<comorbilities>), Column('interstitial_lung_disease', BOOLEAN(), table=<comorbilities>), Column('tuberculosis', BOOLEAN(), table=<comorbilities>), Column('asthma', BOOLEAN(), table=<comorbilities>), Column('cardiovascular_disease', BOOLEAN(), table=<comorbilities>), Column('renal_disease', BOOLEAN(), table
# ...
